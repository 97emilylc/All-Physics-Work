# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

def data_gen():
    t = data_gen.t
    cnt = 0
    while cnt < 1000:
        cnt+=1
        t += 0.05
        yield t, np.sin(2*np.pi*t) * np.exp(-t/10.)
data_gen.t = 0

fig, ax = plt.subplots()
line, = ax.plot([], [], lw=2)
ax.set_ylim(-1.1, 1.1)
ax.set_xlim(0, 5)
ax.grid()
xdata, ydata = [], []
def run(data):
    # update the data
    t,y = data
    xdata.append(t)
    ydata.append(y)
    xmin, xmax = ax.get_xlim()

    if t >= xmax:
        ax.set_xlim(xmin, 1.2*xmax)
        ax.figure.canvas.draw()
    line.set_data(xdata, ydata)

    return line,

ani = animation.FuncAnimation(fig, run, data_gen, blit=True, interval=20,
    repeat=False)
plt.show()

# %%
import guidata
guidata.qapplication() # not required if a QApplication has already been created

import guidata.dataset.datatypes as dt
import guidata.dataset.dataitems as di

class Processing(dt.DataSet):
    """Example"""
    a = di.FloatItem("Parameter #1", default=2.3)
    b = di.IntItem("Parameter #2", min=0, max=10, default=5)
    type = di.ChoiceItem("Processing algorithm",
                         ("type 1", "type 2", "type 3"))

param = Processing()
param.edit()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-7-1ab23af02093> in <module>()
# ----> 1 import guidata
#       2 guidata.qapplication() # not required if a QApplication has already been created
#       3
#       4 import guidata.dataset.datatypes as dt
#       5 import guidata.dataset.dataitems as di
#
# ImportError: No module named 'guidata'

# %%
import guidata
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-8-c3d23e84aa28> in <module>()
# ----> 1 import guidata
#
# ImportError: No module named 'guidata'

# %%
result = integrate.quad(lambda x: special.jv(2.5,x), 0, 4.5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-a668e5b1d9c2> in <module>()
# ----> 1 result = integrate.quad(lambda x: special.jv(2.5,x), 0, 4.5)
#
# NameError: name 'integrate' is not defined

# %%
import all
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-10-e9fbff0f2a30> in <module>()
# ----> 1 import all
#
# ImportError: No module named 'all'

# %%
import scipy

# %%
result = integrate.quad(lambda x: special.jv(2.5,x), 0, 4.5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-a668e5b1d9c2> in <module>()
# ----> 1 result = integrate.quad(lambda x: special.jv(2.5,x), 0, 4.5)
#
# NameError: name 'integrate' is not defined
