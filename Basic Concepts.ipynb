# %%
ls
# Out:
#  Volume in drive C is TI106042W0A
#  Volume Serial Number is E4E2-383E
#
#  Directory of C:\Users\Alec M Sim\Documents\IPython Notebooks
#
# 07/17/2014  12:48 PM    <DIR>          .
# 07/17/2014  12:48 PM    <DIR>          ..
# 07/17/2014  12:45 PM    <DIR>          .ipynb_checkpoints
# 07/17/2014  12:41 PM               189 Basic Concepts.ipynb
# 07/17/2014  12:13 PM           164,192 Exploring beat frequencies.ipynb
# 07/17/2014  12:39 PM             2,808 Markdown basics test.ipynb
# 07/17/2014  12:45 PM            10,273 notebook.ipynb
# 07/17/2014  12:45 PM             7,821 notebook1.ipynb
# 07/17/2014  09:47 AM            64,653 Test Notebook.ipynb
# 07/17/2014  12:48 PM            17,016 test.ipynb
# 07/17/2014  11:37 AM             5,559 Widgets TEST.ipynb
#                8 File(s)        272,511 bytes
#                3 Dir(s)  81,706,172,416 bytes free

# %%
pwd
# Out:
# 'C:\\Users\\Alec M Sim\\Documents\\IPython Notebooks'

# %%
import re

# %%
re.sub(Ellipsis)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-4f84c7fafab3> in <module>()
# ----> 1 re.sub(Ellipsis)
#
# TypeError: sub() missing 2 required positional arguments: 'repl' and 'string'

# %%
# %pypy
# Out:
# ERROR: Line magic function `%pypy` not found (But cell magic `%%pypy` exists, did you mean that instead?).

# %%
# %quickref

# %%
ls
# Out:
#  Volume in drive C is TI106042W0A
#  Volume Serial Number is E4E2-383E
#
#  Directory of C:\Users\Alec M Sim\Documents\IPython Notebooks
#
# 07/17/2014  12:48 PM    <DIR>          .
# 07/17/2014  12:48 PM    <DIR>          ..
# 07/17/2014  12:59 PM    <DIR>          .ipynb_checkpoints
# 07/17/2014  01:13 PM             4,782 Basic Concepts.ipynb
# 07/17/2014  12:13 PM           164,192 Exploring beat frequencies.ipynb
# 07/17/2014  12:39 PM             2,808 Markdown basics test.ipynb
# 07/17/2014  12:45 PM            10,273 notebook.ipynb
# 07/17/2014  12:45 PM             7,821 notebook1.ipynb
# 07/17/2014  09:47 AM            64,653 Test Notebook.ipynb
# 07/17/2014  12:48 PM            17,016 test.ipynb
# 07/17/2014  11:37 AM             5,559 Widgets TEST.ipynb
#                8 File(s)        277,104 bytes
#                3 Dir(s)  83,101,028,352 bytes free

# %%
https://github.com/jakevdp/JSAnimation.git
# Out:
#   File "<ipython-input-14-e55c410ce8e4>", line 1
#     https://github.com/jakevdp/JSAnimation.git
#          ^
# SyntaxError: invalid syntax

# %%
ls
# Out:
#  Volume in drive C is TI106042W0A
#  Volume Serial Number is E4E2-383E
#
#  Directory of C:\Users\Alec M Sim\Documents\IPython Notebooks
#
# 07/17/2014  12:48 PM    <DIR>          .
# 07/17/2014  12:48 PM    <DIR>          ..
# 07/17/2014  12:59 PM    <DIR>          .ipynb_checkpoints
# 07/17/2014  01:41 PM             6,300 Basic Concepts.ipynb
# 07/17/2014  12:13 PM           164,192 Exploring beat frequencies.ipynb
# 07/17/2014  12:39 PM             2,808 Markdown basics test.ipynb
# 07/17/2014  12:45 PM            10,273 notebook.ipynb
# 07/17/2014  12:45 PM             7,821 notebook1.ipynb
# 07/17/2014  09:47 AM            64,653 Test Notebook.ipynb
# 07/17/2014  12:48 PM            17,016 test.ipynb
# 07/17/2014  11:37 AM             5,559 Widgets TEST.ipynb
#                8 File(s)        278,622 bytes
#                3 Dir(s)  82,668,138,496 bytes free
