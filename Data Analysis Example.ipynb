# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from pylab import *

# %% [markdown]
# Here the file is imported.  note that the file must be in the active directory of the Notebook that we are using.  If not a number of errors wil be generated on execution.

# %%
x = pd.read_excel('LDPE 1mil Plate 4_Electrode A1_7092 V_ 258.8 MV per m(PeakEventsONLY).xlsx', sheet_name='Sheet1', parse_cols=[0])

# %%
y = pd.read_excel('LDPE 1mil Plate 4_Electrode A1_7092 V_ 258.8 MV per m(PeakEventsONLY).xlsx', sheet_name='Sheet1', parse_cols=[2])

# %% [markdown]
# data = pd.DataFrame(raw_dat, columns=["X", "Y", "Z"])

# %%
# %matplotlib inline
plot(x, y)
xlabel('index (No Units)')
ylabel('Data (No-Units)')
title('About as simple as it gets, folks')
grid(True)
#savefig("test.png")This is a nice quick save feature that could be used to batch process the data.
show()
