# %% [markdown]
# #A. The largest heading

# %% [markdown]
# ##The second larges heading

# %% [markdown]
# #### Here five "#" means that this is the 5th largest heading more "#" means next heading

# %% [markdown]
# SO thats how we do headings

# %% [markdown]
# # B. Blockquotes

# %% [markdown]
# You can indicate blockquotes wth a >

# %% [markdown]
# In the words of Abraham LIncoln:
# > Pardon my English

# %% [markdown]
# # C. Styling text

# %% [markdown]
# *This text is italic*
#
# **This text will be bold**

# %% [markdown]
# ### 1. This is another way to do the same thing

# %% [markdown]
# _This is guess what text_

# %% [markdown]
# __And this is bold stuff__

# %% [markdown]
# #Introdction
#
# The notebook extends the console-based approach to interactiv computing in a qulitatiely new direction, providing a web-based application suitable for capturing the whole comutation process:

# %% [markdown]
# #### A web application:

# %% [markdown]
# this is a test, that shows how to use the m shortcut to set the state of the text as markdown.
